# %% [markdown]
# # Clustering Crypto

# %%
# !pip install -U altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 9.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.11.1)
# Requirement already satisfied, skipping upgrade: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.18.1)
# Requirement already satisfied, skipping upgrade: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.0.1)
# Requirement already satisfied, skipping upgrade: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (3.2.0)
# Requirement already satisfied, skipping upgrade: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.10.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (1.14.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (1.5.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (0.15.7)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair) (2.2.0)
# Installing collected packages: altair
# Successfully installed altair-4.1.0
# WARNING: You are using pip version 20.0.2; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# Initial imports
import requests
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np
import altair as alt

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
# url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")
file_path = Path("Data/crypto_data.csv")
# Create a DataFrame
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df[['CoinName',
           'Algorithm',
           'IsTrading',
           'ProofType',
           'TotalCoinsMined',
           'TotalCoinSupply']]
crypto_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df["Algorithm"] != "N/A"]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns = "IsTrading")

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
crypto_df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df["TotalCoinsMined"] != 0]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df.loc[crypto_df["TotalCoinSupply"] != 'N/A']
crypto_df = crypto_df.loc[crypto_df["ProofType"] != 'N/A']

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns = "CoinName")
crypto_df.head(10)
# Out:
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10    314159265359
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0
# LTC           Scrypt       PoW     6.303924e+07        84000000
# DASH             X11   PoW/PoS     9.031294e+06        22000000
# XMR   CryptoNight-V7       PoW     1.720114e+07               0
# ETC           Ethash       PoW     1.133597e+08       210000000
# ZEC         Equihash       PoW     7.383056e+06        21000000

# %%
# Create dummy variables for text features        
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'], drop_first=True)

# %%
# Standardize data
X = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(X)

# %%
# Create a DataFrame with the principal components data
pca_df = pd.DataFrame(data=crypto_pca, 
                      columns=["PC 1", "PC 2", "PC 3"],
                      index=crypto_df.index
                     )
pca_df.head()
# Out:
#           PC 1      PC 2      PC 3
# 42   -0.327809  0.984668 -0.542130
# 404  -0.311130  0.984681 -0.542475
# 1337  2.317142  1.567985 -0.629156
# BTC  -0.154991 -1.299714  0.178259
# ETH  -0.161684 -1.956253  0.390675

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pca_df)
    inertia.append(km.inertia_)


# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
alt.Chart(df_elbow).mark_line().encode(x="k", y="inertia")
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pca_df)

# Predict clusters
predictions = model.predict(pca_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.DataFrame({
    "Algorithm": crypto_df["Algorithm"],
    "ProofType": crypto_df["ProofType"],
    "TotalCoinsMined": crypto_df["TotalCoinsMined"],
    "TotalCoinSupply": crypto_df["TotalCoinSupply"],
    "PC 1": pca_df["PC 1"],
    "PC 2": pca_df["PC 2"],
    "PC 3": pca_df["PC 3"],
    "CoinName": coins_name["CoinName"],
    "Class": model.labels_,
    },
    index=crypto_df.index
)
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.327809  0.984668
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.311130  0.984681
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.317142  1.567985
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.154991 -1.299714
# ETH     Ethash       PoW     1.076842e+08               0 -0.161684 -1.956253
#
#           PC 3   CoinName  Class
# 42   -0.542130    42 Coin      0
# 404  -0.542475    404Coin      0
# 1337 -0.629156  EliteCoin      0
# BTC   0.178259    Bitcoin      1
# ETH   0.390675   Ethereum      1

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters

alt.Chart(clustered_df).mark_circle().encode(x="PC 1", y="PC 2")
# Out:
# alt.Chart(...)

# %%
alt.Chart(clustered_df).mark_circle(
    size=100
).encode(
    alt.X("PC 1", title="PC 1", scale=alt.Scale(zero=False)),
    alt.Y("PC 2", title="PC 2", scale=alt.Scale(zero=False)),
    color="Class",
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"]
).properties(
    height=300,
    width=300,
    title="PC 1 vs PC 2").interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
table = pd.DataFrame(clustered_df, columns=["CoinName", 
                             "Algorithm", 
                             "ProofType", 
                             "TotalCoinSupply", 
                             "TotalCoinsMined", 
                             "Class"]
                    )
display(table)
# Out:
#          CoinName    Algorithm ProofType TotalCoinSupply  TotalCoinsMined  \
# 42        42 Coin       Scrypt   PoW/PoS              42     4.199995e+01
# 404       404Coin       Scrypt   PoW/PoS       532000000     1.055185e+09
# 1337    EliteCoin          X13   PoW/PoS    314159265359     2.927942e+10
# BTC       Bitcoin      SHA-256       PoW        21000000     1.792718e+07
# ETH      Ethereum       Ethash       PoW               0     1.076842e+08
# ...           ...          ...       ...             ...              ...
# ZEPH       ZEPHYR      SHA-256      DPoS      2000000000     2.000000e+09
# GAP       Gapcoin       Scrypt   PoW/PoS       250000000     1.493105e+07
# BDX        Beldex  CryptoNight       PoW      1400222610     9.802226e+08
# ZEN       Horizen     Equihash       PoW        21000000     7.296538e+06
# XBC   BitcoinPlus       Scrypt       PoS         1000000     1.283270e+05
#
#       Class
# 42        0
# 404       0
# 1337      0
# BTC       1
# ETH       1
# ...     ...
# ZEPH      0
# GAP       0
# BDX       1
# ZEN       1
# XBC       0
#
# [533 rows x 6 columns]

# %%
# Print the total number of tradable cryptocurrencies
print(f'The total number of tradable cryptocurrenices is: {len(clustered_df)}')
# Out:
# The total number of tradable cryptocurrenices is: 533

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
scaler = MinMaxScaler()

normalize_columns = ['TotalCoinsMined', 'TotalCoinSupply']
x = crypto_df[normalize_columns].values
x_scaled = scaler.fit_transform(x)

tradable_df = pd.DataFrame(x_scaled, columns=normalize_columns, index=crypto_df.index).reset_index()

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
alt.Chart(tradable_df).mark_circle().encode(x="TotalCoinsMined", y="TotalCoinSupply")
# Out:
# alt.Chart(...)
